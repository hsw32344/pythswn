# %% [markdown]
# # python索引
# - 索引是偏移量，分为正偏移和负偏移
# - 正偏移基于第一个元素开始偏移，0代表第一个元素（不偏移）
# - 负偏移基于最后一个元素的右边界，-1代表最后一个元素（向左偏移1）
# - 正偏移 = 负偏移 + length
# # python步长
# - 步长(step)是每次给“当前索引”增加的偏移量
# - 下一索引 = 当前索引 + step
# - step = 1 代表正向连续取值，step = -1 代表负向连续取值，以此类推
